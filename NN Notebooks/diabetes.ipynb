# %%
import pandas as pd
import numpy as np
import tensorflow
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib import pyplot

from tensorflow.keras.optimizers import SGD, RMSprop, Adagrad, Adadelta, Adagrad, Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# %%
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.Outcome.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# check missing
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X = df.drop(['Outcome'],axis=1)
y = df.Outcome

# %%
# Split X and Y
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.10, stratify = y, random_state = 987)
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size = 0.15, stratify = y_train, random_state = 987)
print(X_train.shape,y_train.shape)
print(X_val.shape,y_val.shape)
print(X_test.shape,y_test.shape)
# Out:
# (587, 8) (587,)
# (104, 8) (104,)
# (77, 8) (77,)

# %%
# 5-point summary describe()
# univaritae analysis
# bi-variate analysis
# pairplot - multi variate
# correlation matrix
# feature selection

# %%
# lets scale
scaler = StandardScaler()
X_train_scale = scaler.fit_transform(X_train)
X_val_scale = scaler.transform(X_val)
X_test_scale = scaler.transform(X_test)

# %%
# Shape of input === number of features
print(X_train_scale.shape[1],)
# Out:
# 8

# %%
# Lets build the Model
model = Sequential()
# No of Input will be == (total number of train examples , 8)
# where 8 = feature
model.add(Input(shape=(X_train_scale.shape[1],)))

# Hidden Layer 1
model.add(Dense(units=64,activation='relu'))
# Hidden Layer 2
model.add(Dense(units=32,activation='relu'))
# Hidden Layer 3
model.add(Dense(units=16,activation='relu'))

# Output Layer - this is a binary classification
model.add(Dense(units=1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                576
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 3201 (12.50 KB)
# Trainable params: 3201 (12.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_scale,y_train,
                    validation_data=(X_val_scale, y_val),epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 2s 21ms/step - loss: 0.6365 - accuracy: 0.6831 - val_loss: 0.5887 - val_accuracy: 0.7500
# Epoch 2/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5607 - accuracy: 0.7513 - val_loss: 0.5302 - val_accuracy: 0.7788
# Epoch 3/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.7700 - val_loss: 0.4887 - val_accuracy: 0.7692
# Epoch 4/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4757 - accuracy: 0.7717 - val_loss: 0.4627 - val_accuracy: 0.7596
# Epoch 5/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4546 - accuracy: 0.7819 - val_loss: 0.4442 - val_accuracy: 0.7596
# Epoch 6/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4466 - accuracy: 0.7905 - val_loss: 0.4454 - val_accuracy: 0.7692
# Epoch 7/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4348 - accuracy: 0.7956 - val_loss: 0.4506 - val_accuracy: 0.7788
# Epoch 8/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4307 - accuracy: 0.8007 - val_loss: 0.4403 - val_accuracy: 0.7788
# Epoch 9/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4240 - accuracy: 0.7888 - val_loss: 0.4407 - val_accuracy: 0.7692
# Epoch 10/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4194 - accuracy: 0.7905 - val_loss: 0.4428 - val_accuracy: 0.7596
# Epoch 11/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4151 - accuracy: 0.7973 - val_loss: 0.4378 - val_accuracy: 0.7885
# Epoch 12/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4120 - accuracy: 0.8024 - val_loss: 0.4461 - val_accuracy: 0.7692
# Epoch 13/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4086 - accuracy: 0.8041 - val_loss: 0.4391 - val_accuracy: 0.7981
# Epoch 14/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.8024 - val_loss: 0.4439 - val_accuracy: 0.7692
# Epoch 15/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4007 - accuracy: 0.8041 - val_loss: 0.4365 - val_accuracy: 0.7981
# Epoch 16/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3995 - accuracy: 0.8075 - val_loss: 0.4450 - val_accuracy: 0.7981
# Epoch 17/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3953 - accuracy: 0.8109 - val_loss: 0.4349 - val_accuracy: 0.8077
# Epoch 18/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3918 - accuracy: 0.8109 - val_loss: 0.4442 - val_accuracy: 0.7692
# Epoch 19/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3906 - accuracy: 0.8109 - val_loss: 0.4380 - val_accuracy: 0.7981
# Epoch 20/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3860 - accuracy: 0.8245 - val_loss: 0.4532 - val_accuracy: 0.7788
# Epoch 21/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3825 - accuracy: 0.8160 - val_loss: 0.4494 - val_accuracy: 0.7788
# Epoch 22/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3803 - accuracy: 0.8262 - val_loss: 0.4521 - val_accuracy: 0.7885
# Epoch 23/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3762 - accuracy: 0.8245 - val_loss: 0.4466 - val_accuracy: 0.7885
# Epoch 24/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3756 - accuracy: 0.8211 - val_loss: 0.4413 - val_accuracy: 0.7981
# Epoch 25/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3700 - accuracy: 0.8245 - val_loss: 0.4466 - val_accuracy: 0.7692
# Epoch 26/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3680 - accuracy: 0.8211 - val_loss: 0.4384 - val_accuracy: 0.8077
# Epoch 27/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3654 - accuracy: 0.8194 - val_loss: 0.4544 - val_accuracy: 0.7885
# Epoch 28/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3637 - accuracy: 0.8382 - val_loss: 0.4517 - val_accuracy: 0.7981
# Epoch 29/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3593 - accuracy: 0.8313 - val_loss: 0.4563 - val_accuracy: 0.7692
# Epoch 30/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3564 - accuracy: 0.8279 - val_loss: 0.4575 - val_accuracy: 0.7885
# Epoch 31/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3519 - accuracy: 0.8382 - val_loss: 0.4559 - val_accuracy: 0.7885
# Epoch 32/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3532 - accuracy: 0.8279 - val_loss: 0.4496 - val_accuracy: 0.7981
# Epoch 33/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3508 - accuracy: 0.8399 - val_loss: 0.4554 - val_accuracy: 0.7981
# Epoch 34/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3431 - accuracy: 0.8399 - val_loss: 0.4568 - val_accuracy: 0.7885
# Epoch 35/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3411 - accuracy: 0.8399 - val_loss: 0.4562 - val_accuracy: 0.8077
# Epoch 36/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3409 - accuracy: 0.8365 - val_loss: 0.4649 - val_accuracy: 0.8077
# Epoch 37/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3340 - accuracy: 0.8382 - val_loss: 0.4526 - val_accuracy: 0.8269
# Epoch 38/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3322 - accuracy: 0.8501 - val_loss: 0.4506 - val_accuracy: 0.8173
# Epoch 39/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3279 - accuracy: 0.8450 - val_loss: 0.4492 - val_accuracy: 0.8269
# Epoch 40/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3245 - accuracy: 0.8518 - val_loss: 0.4614 - val_accuracy: 0.8269
# Epoch 41/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3271 - accuracy: 0.8433 - val_loss: 0.4578 - val_accuracy: 0.7885
# Epoch 42/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3180 - accuracy: 0.8450 - val_loss: 0.4728 - val_accuracy: 0.7885
# Epoch 43/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3113 - accuracy: 0.8569 - val_loss: 0.4714 - val_accuracy: 0.8269
# Epoch 44/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3107 - accuracy: 0.8654 - val_loss: 0.4708 - val_accuracy: 0.8462
# Epoch 45/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3097 - accuracy: 0.8569 - val_loss: 0.5046 - val_accuracy: 0.7404
# Epoch 46/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3098 - accuracy: 0.8671 - val_loss: 0.4668 - val_accuracy: 0.8269
# Epoch 47/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2976 - accuracy: 0.8739 - val_loss: 0.4772 - val_accuracy: 0.7788
# Epoch 48/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2927 - accuracy: 0.8688 - val_loss: 0.4756 - val_accuracy: 0.7981
# Epoch 49/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2895 - accuracy: 0.8722 - val_loss: 0.4925 - val_accuracy: 0.7692
# Epoch 50/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2874 - accuracy: 0.8756 - val_loss: 0.4775 - val_accuracy: 0.8173
# Epoch 51/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2842 - accuracy: 0.8773 - val_loss: 0.4941 - val_accuracy: 0.7981
# Epoch 52/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2775 - accuracy: 0.8825 - val_loss: 0.4966 - val_accuracy: 0.7788
# Epoch 53/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2754 - accuracy: 0.8842 - val_loss: 0.4956 - val_accuracy: 0.7981
# Epoch 54/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2745 - accuracy: 0.8790 - val_loss: 0.5065 - val_accuracy: 0.7692
# Epoch 55/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2659 - accuracy: 0.8910 - val_loss: 0.4850 - val_accuracy: 0.8269
# Epoch 56/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2637 - accuracy: 0.8893 - val_loss: 0.5020 - val_accuracy: 0.8077
# Epoch 57/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2609 - accuracy: 0.8978 - val_loss: 0.4975 - val_accuracy: 0.8269
# Epoch 58/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2604 - accuracy: 0.8944 - val_loss: 0.5127 - val_accuracy: 0.7981
# Epoch 59/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2555 - accuracy: 0.8927 - val_loss: 0.5195 - val_accuracy: 0.7885
# Epoch 60/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2483 - accuracy: 0.9029 - val_loss: 0.5347 - val_accuracy: 0.7885
# Epoch 61/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2450 - accuracy: 0.9114 - val_loss: 0.5111 - val_accuracy: 0.8173
# Epoch 62/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2415 - accuracy: 0.9012 - val_loss: 0.5204 - val_accuracy: 0.8077
# Epoch 63/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2362 - accuracy: 0.9080 - val_loss: 0.5357 - val_accuracy: 0.7981
# Epoch 64/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2365 - accuracy: 0.9080 - val_loss: 0.5189 - val_accuracy: 0.7885
# Epoch 65/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2328 - accuracy: 0.9114 - val_loss: 0.5385 - val_accuracy: 0.7885
# Epoch 66/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2250 - accuracy: 0.9148 - val_loss: 0.5634 - val_accuracy: 0.7308
# Epoch 67/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2229 - accuracy: 0.9165 - val_loss: 0.5199 - val_accuracy: 0.8173
# Epoch 68/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2198 - accuracy: 0.9131 - val_loss: 0.5643 - val_accuracy: 0.7885
# Epoch 69/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2160 - accuracy: 0.9097 - val_loss: 0.5707 - val_accuracy: 0.7692
# Epoch 70/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2142 - accuracy: 0.9233 - val_loss: 0.5819 - val_accuracy: 0.7981
# Epoch 71/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2105 - accuracy: 0.9233 - val_loss: 0.5659 - val_accuracy: 0.7885
# Epoch 72/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2116 - accuracy: 0.9199 - val_loss: 0.5994 - val_accuracy: 0.7596
# Epoch 73/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2044 - accuracy: 0.9233 - val_loss: 0.6257 - val_accuracy: 0.7500
# Epoch 74/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2248 - accuracy: 0.9080 - val_loss: 0.5902 - val_accuracy: 0.7692
# Epoch 75/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1973 - accuracy: 0.9336 - val_loss: 0.6167 - val_accuracy: 0.8173
# Epoch 76/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1874 - accuracy: 0.9404 - val_loss: 0.6042 - val_accuracy: 0.7692
# Epoch 77/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1843 - accuracy: 0.9421 - val_loss: 0.6172 - val_accuracy: 0.7596
# Epoch 78/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1827 - accuracy: 0.9319 - val_loss: 0.6347 - val_accuracy: 0.7596
# Epoch 79/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1922 - accuracy: 0.9336 - val_loss: 0.6355 - val_accuracy: 0.7788
# Epoch 80/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1774 - accuracy: 0.9370 - val_loss: 0.6012 - val_accuracy: 0.7981
# Epoch 81/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1692 - accuracy: 0.9455 - val_loss: 0.6318 - val_accuracy: 0.7885
# Epoch 82/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1694 - accuracy: 0.9387 - val_loss: 0.6494 - val_accuracy: 0.7885
# Epoch 83/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1657 - accuracy: 0.9472 - val_loss: 0.6625 - val_accuracy: 0.7885
# Epoch 84/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1571 - accuracy: 0.9574 - val_loss: 0.6352 - val_accuracy: 0.7788
# Epoch 85/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1552 - accuracy: 0.9489 - val_loss: 0.6909 - val_accuracy: 0.7885
# Epoch 86/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1627 - accuracy: 0.9438 - val_loss: 0.6629 - val_accuracy: 0.7788
# Epoch 87/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1549 - accuracy: 0.9523 - val_loss: 0.6516 - val_accuracy: 0.7885
# Epoch 88/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1563 - accuracy: 0.9489 - val_loss: 0.7151 - val_accuracy: 0.7885
# Epoch 89/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1475 - accuracy: 0.9523 - val_loss: 0.7043 - val_accuracy: 0.8077
# Epoch 90/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1413 - accuracy: 0.9608 - val_loss: 0.6903 - val_accuracy: 0.7885
# Epoch 91/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1358 - accuracy: 0.9642 - val_loss: 0.7048 - val_accuracy: 0.7885
# Epoch 92/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1332 - accuracy: 0.9659 - val_loss: 0.7143 - val_accuracy: 0.7788
# Epoch 93/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1390 - accuracy: 0.9608 - val_loss: 0.7266 - val_accuracy: 0.7885
# Epoch 94/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1374 - accuracy: 0.9574 - val_loss: 0.6968 - val_accuracy: 0.7885
# Epoch 95/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1257 - accuracy: 0.9676 - val_loss: 0.7382 - val_accuracy: 0.7788
# Epoch 96/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1246 - accuracy: 0.9676 - val_loss: 0.7284 - val_accuracy: 0.7788
# Epoch 97/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1195 - accuracy: 0.9693 - val_loss: 0.7699 - val_accuracy: 0.7788
# Epoch 98/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1164 - accuracy: 0.9659 - val_loss: 0.7248 - val_accuracy: 0.7500
# Epoch 99/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1212 - accuracy: 0.9693 - val_loss: 0.7969 - val_accuracy: 0.7692
# Epoch 100/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1174 - accuracy: 0.9642 - val_loss: 0.7545 - val_accuracy: 0.7788

# %%
y_pred_train= model.predict(X_train_scale)
y_test_train=model.predict(X_test_scale)

# %%
model.save('a_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# !wget <URL>

# %%
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Let add regularization - Dropout

# %%
# Lets build the Model
model = Sequential()
# No of Input will be == (total number of train examples , 8)
# where 8 = feature
model.add(Input(shape=(X_train_scale.shape[1],)))

# Hidden Layer 1
model.add(Dense(units=64,activation='relu'))
model.add(Dropout(0.2))
# Hidden Layer 2
model.add(Dense(units=32,activation='relu'))
model.add(Dropout(0.2))
# Hidden Layer 3
model.add(Dense(units=16,activation='relu'))
model.add(Dropout(0.2))

# Output Layer - this is a binary classification
model.add(Dense(units=1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 64)                576
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 3201 (12.50 KB)
# Trainable params: 3201 (12.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_scale,y_train,validation_data=(X_val_scale, y_val),epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 20ms/step - loss: 0.6938 - accuracy: 0.5281 - val_loss: 0.6692 - val_accuracy: 0.6346
# Epoch 2/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6434 - accuracy: 0.6763 - val_loss: 0.6273 - val_accuracy: 0.6538
# Epoch 3/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6105 - accuracy: 0.6899 - val_loss: 0.5781 - val_accuracy: 0.7019
# Epoch 4/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5523 - accuracy: 0.7291 - val_loss: 0.5311 - val_accuracy: 0.7404
# Epoch 5/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5266 - accuracy: 0.7394 - val_loss: 0.5104 - val_accuracy: 0.7404
# Epoch 6/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %%
y_pred_train= model.predict(X_train_scale)
y_test_train=model.predict(X_test_scale)

# %%
cm = confusion_matrix(y_pred=y_pred_train > 0.5,y_true=y_train)
cm
# Out:
# array([[348,  34],
#        [ 51, 154]])

# %%
cm = confusion_matrix(y_pred=y_test_train > 0.5,y_true=y_test)
cm
# Out:
# array([[36, 14],
#        [ 8, 19]])

# %% [markdown]
# # Add Batch Norm

# %%
# Lets build the Model
model = Sequential()
# No of Input will be == (total number of train examples , 8)
# where 8 = feature
model.add(Input(shape=(X_train_scale.shape[1],)))

# Hidden Layer 1
model.add(Dense(units=64,activation='relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
# Hidden Layer 2
model.add(Dense(units=32,activation='relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
# Hidden Layer 3
model.add(Dense(units=16,activation='relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())

# Output Layer - this is a binary classification
model.add(Dense(units=1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                576
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  batch_normalization (Batch  (None, 64)                256
#  Normalization)
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dense_10 (Dense)            (None, 16)                528
#
#  dropout_5 (Dropout)         (None, 16)                0
#
#  batch_normalization_2 (Bat  (None, 16)                64
#  chNormalization)
#
#  dense_11 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 3649 (14.25 KB)
# Trainable params: 3425 (13.38 KB)
# Non-trainable params: 224 (896.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_scale,y_train,validation_data=(X_val_scale, y_val),epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 2s 17ms/step - loss: 0.8240 - accuracy: 0.5639 - val_loss: 0.6277 - val_accuracy: 0.7596
# Epoch 2/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6601 - accuracy: 0.6627 - val_loss: 0.5831 - val_accuracy: 0.7885
# Epoch 3/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6229 - accuracy: 0.6951 - val_loss: 0.5586 - val_accuracy: 0.7885
# Epoch 4/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6247 - accuracy: 0.6917 - val_loss: 0.5424 - val_accuracy: 0.7788
# Epoch 5/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5681 - accuracy: 0.7070 - val_loss: 0.5277 - val_accuracy: 0.7692
# Epoch 6/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5719 - accuracy: 0.7189 - val_loss: 0.5194 - val_accuracy: 0.7596
# Epoch 7/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5307 - accuracy: 0.7632 - val_loss: 0.5113 - val_accuracy: 0.7596
# Epoch 8/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5342 - accuracy: 0.7462 - val_loss: 0.5036 - val_accuracy: 0.7692
# Epoch 9/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5547 - accuracy: 0.7394 - val_loss: 0.4979 - val_accuracy: 0.7788
# Epoch 10/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5185 - accuracy: 0.7581 - val_loss: 0.4959 - val_accuracy: 0.7788
# Epoch 11/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5713 - accuracy: 0.7257 - val_loss: 0.4974 - val_accuracy: 0.7692
# Epoch 12/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5513 - accuracy: 0.7257 - val_loss: 0.4887 - val_accuracy: 0.7788
# Epoch 13/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5146 - accuracy: 0.7700 - val_loss: 0.4895 - val_accuracy: 0.7885
# Epoch 14/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5259 - accuracy: 0.7376 - val_loss: 0.4925 - val_accuracy: 0.7885
# Epoch 15/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4849 - accuracy: 0.7734 - val_loss: 0.4922 - val_accuracy: 0.7885
# Epoch 16/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5174 - accuracy: 0.7530 - val_loss: 0.4889 - val_accuracy: 0.7885
# Epoch 17/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4793 - accuracy: 0.7632 - val_loss: 0.4871 - val_accuracy: 0.7885
# Epoch 18/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.5034 - accuracy: 0.7530 - val_loss: 0.4930 - val_accuracy: 0.7885
# Epoch 19/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5081 - accuracy: 0.7581 - val_loss: 0.4920 - val_accuracy: 0.7885
# Epoch 20/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4814 - accuracy: 0.7717 - val_loss: 0.4864 - val_accuracy: 0.7788
# Epoch 21/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4896 - accuracy: 0.7513 - val_loss: 0.4781 - val_accuracy: 0.7788
# Epoch 22/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4598 - accuracy: 0.8007 - val_loss: 0.4745 - val_accuracy: 0.7981
# Epoch 23/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4816 - accuracy: 0.7581 - val_loss: 0.4706 - val_accuracy: 0.7885
# Epoch 24/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5051 - accuracy: 0.7564 - val_loss: 0.4664 - val_accuracy: 0.7981
# Epoch 25/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4659 - accuracy: 0.7819 - val_loss: 0.4555 - val_accuracy: 0.7981
# Epoch 26/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4715 - accuracy: 0.7734 - val_loss: 0.4570 - val_accuracy: 0.8173
# Epoch 27/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5036 - accuracy: 0.7479 - val_loss: 0.4640 - val_accuracy: 0.7788
# Epoch 28/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4967 - accuracy: 0.7513 - val_loss: 0.4692 - val_accuracy: 0.7788
# Epoch 29/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4675 - accuracy: 0.7819 - val_loss: 0.4699 - val_accuracy: 0.7788
# Epoch 30/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4682 - accuracy: 0.7632 - val_loss: 0.4708 - val_accuracy: 0.7788
# Epoch 31/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4808 - accuracy: 0.7666 - val_loss: 0.4720 - val_accuracy: 0.7692
# Epoch 32/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4960 - accuracy: 0.7479 - val_loss: 0.4643 - val_accuracy: 0.7981
# Epoch 33/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4402 - accuracy: 0.7734 - val_loss: 0.4679 - val_accuracy: 0.7885
# Epoch 34/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4713 - accuracy: 0.7871 - val_loss: 0.4691 - val_accuracy: 0.7692
# Epoch 35/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4751 - accuracy: 0.7836 - val_loss: 0.4712 - val_accuracy: 0.7692
# Epoch 36/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4881 - accuracy: 0.7649 - val_loss: 0.4722 - val_accuracy: 0.7692
# Epoch 37/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4715 - accuracy: 0.7717 - val_loss: 0.4670 - val_accuracy: 0.7788
# Epoch 38/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4743 - accuracy: 0.7615 - val_loss: 0.4664 - val_accuracy: 0.7692
# Epoch 39/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4521 - accuracy: 0.7802 - val_loss: 0.4595 - val_accuracy: 0.7885
# Epoch 40/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4729 - accuracy: 0.7564 - val_loss: 0.4621 - val_accuracy: 0.7788
# Epoch 41/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4760 - accuracy: 0.7700 - val_loss: 0.4622 - val_accuracy: 0.7788
# Epoch 42/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4755 - accuracy: 0.7547 - val_loss: 0.4665 - val_accuracy: 0.7788
# Epoch 43/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4347 - accuracy: 0.7956 - val_loss: 0.4672 - val_accuracy: 0.7692
# Epoch 44/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4280 - accuracy: 0.8024 - val_loss: 0.4656 - val_accuracy: 0.7692
# Epoch 45/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4304 - accuracy: 0.7990 - val_loss: 0.4650 - val_accuracy: 0.7885
# Epoch 46/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4585 - accuracy: 0.7871 - val_loss: 0.4614 - val_accuracy: 0.7885
# Epoch 47/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4636 - accuracy: 0.7496 - val_loss: 0.4647 - val_accuracy: 0.7788
# Epoch 48/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4308 - accuracy: 0.8007 - val_loss: 0.4743 - val_accuracy: 0.7692
# Epoch 49/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4318 - accuracy: 0.7990 - val_loss: 0.4748 - val_accuracy: 0.7885
# Epoch 50/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4570 - accuracy: 0.7853 - val_loss: 0.4715 - val_accuracy: 0.7885
# Epoch 51/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4449 - accuracy: 0.7956 - val_loss: 0.4709 - val_accuracy: 0.7885
# Epoch 52/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4450 - accuracy: 0.7717 - val_loss: 0.4662 - val_accuracy: 0.7885
# Epoch 53/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.
100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4454 - accuracy: 0.7990 - val_loss: 0.4627 - val_accuracy: 0.7885
# Epoch 86/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4224 - accuracy: 0.7956 - val_loss: 0.4504 - val_accuracy: 0.8077
# Epoch 87/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4230 - accuracy: 0.7939 - val_loss: 0.4473 - val_accuracy: 0.8077
# Epoch 88/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4408 - accuracy: 0.7990 - val_loss: 0.4517 - val_accuracy: 0.7981
# Epoch 89/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4214 - accuracy: 0.7973 - val_loss: 0.4496 - val_accuracy: 0.7885
# Epoch 90/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4243 - accuracy: 0.7888 - val_loss: 0.4456 - val_accuracy: 0.8077
# Epoch 91/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4261 - accuracy: 0.8007 - val_loss: 0.4553 - val_accuracy: 0.8077
# Epoch 92/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4202 - accuracy: 0.7956 - val_loss: 0.4600 - val_accuracy: 0.7981
# Epoch 93/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4176 - accuracy: 0.8075 - val_loss: 0.4600 - val_accuracy: 0.7788
# Epoch 94/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4106 - accuracy: 0.8177 - val_loss: 0.4472 - val_accuracy: 0.7981
# Epoch 95/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4066 - accuracy: 0.8075 - val_loss: 0.4531 - val_accuracy: 0.7885
# Epoch 96/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4262 - accuracy: 0.8024 - val_loss: 0.4548 - val_accuracy: 0.7981
# Epoch 97/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4189 - accuracy: 0.8092 - val_loss: 0.4523 - val_accuracy: 0.7788
# Epoch 98/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4119 - accuracy: 0.8007 - val_loss: 0.4657 - val_accuracy: 0.7981
# Epoch 99/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4089 - accuracy: 0.7990 - val_loss: 0.4566 - val_accuracy: 0.7981
# Epoch 100/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4014 - accuracy: 0.8194 - val_loss: 0.4587 - val_accuracy: 0.7788

# %%
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.plot(history.history['accuracy'], label='train')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Lets lock down the above model.summary() for now and see some optmizers
#
# # Lets look at various optmizers

# %%
def create_batchnorm_dropout_model():
    # Lets build the Model
    model = Sequential()
    # No of Input will be == (total number of train examples , 8)
    # where 8 = feature
    model.add(Input(shape=(X_train_scale.shape[1],)))

    # Hidden Layer 1
    model.add(Dense(units=64,activation='relu'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    # Hidden Layer 2
    model.add(Dense(units=32,activation='relu'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    # Hidden Layer 3
    model.add(Dense(units=16,activation='relu'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    # Output Layer - this is a binary classification
    model.add(Dense(units=1,activation='sigmoid'))
    return model

# %%
create_batchnorm_dropout_model().summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 64)                576
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  dense_14 (Dense)            (None, 16)                528
#
#  dropout_8 (Dropout)         (None, 16)                0
#
#  batch_normalization_5 (Bat  (None, 16)                64
#  chNormalization)
#
#  dense_15 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 3649 (14.25 KB)
# Trainable params: 3425 (13.38 KB)
# Non-trainable params: 224 (896.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Lets get some intution on what these numbers mean
# ## Check the 1st iteration to find out if the loss is reasonable. Ideally we stop Regularization that mean in this cases no dropout layers and probably no Batch Norm either  to test this out.

# %%
# Check if we have a reason loss value to start withs
m = create_batchnorm_dropout_model()
# Very very low lr and train

m.compile(optimizer=SGD(learning_rate=0.00001),loss='binary_crossentropy',metrics=['accuracy'])
history = m.fit(X_train_scale,y_train,validation_data=(X_val_scale, y_val),epochs=1,verbose=1)

# Question 1 - Does that accuracy value makes sense ??
# Question 2 - Does that loss value makes sense ??
# Out:
# 19/19 [==============================] - 1s 10ms/step - loss: 0.9626 - accuracy: 0.4685 - val_loss: 0.7052 - val_accuracy: 0.4231

# %%
from math import log

-log(.4)
# Out:
# 0.916290731874155

# %%
# Lets try to train a small subset of data and see if it overfits ! should not be much problem
# we must be able to overfit on a small portion of training data
X_small = X_train[0:10]
y_small = y_train[0:10]
# Check if we have a reason loss value to start with
m = create_batchnorm_dropout_model()
# Very very low lr and train

m.compile(optimizer=SGD(learning_rate=0.00001),loss='binary_crossentropy',metrics=['accuracy'])
history = m.fit(X_small,y_small,epochs=100,validation_data=(X_val_scale, y_val),verbose=1)

# ideally we will end up having a overyly overfit model - which is expected
## MODEL seems to have some SANITY

# %%
# Play around with lr and Dropout - to check whats happening - but this is where we start Hyper param tuning.

# %% [markdown]
# # Many many optimizers

# %%
def train_with_optimizers(optimizers):
    figs={}
    axs={}
    Tot = 5
    Cols = 2

    # Compute Rows required

    Rows = Tot // Cols
    Rows += Tot % Cols

    # Create a Position index
    figs = pyplot.figure(figsize=(10, 10))
    Position = range(1,Tot + 1)
    for idx,opt in enumerate(optimizers):
        print(idx, ' -- ' , opt)
        model = create_batchnorm_dropout_model()
        model.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])
        history = model.fit(X_train_scale,y_train,validation_data=(X_val_scale, y_val),epochs=100,verbose=0)
        axs[idx]=figs.add_subplot(Rows,Cols,Position[idx])
        pyplot.plot(history.history['val_accuracy'], label='test')
        pyplot.plot(history.history['accuracy'], label='train')
        pyplot.legend()
        pyplot.title(idx)
    pyplot.show()

# %%
lr = 1e-2
# SGD
sgd = SGD(learning_rate=lr)
# SGD with Momentum
sgd_with_momentum = SGD(learning_rate=lr, momentum=0.09)
# SGD with Momentum and Nestrov
sgd_with_momentum_nestrov = SGD(learning_rate=lr, momentum=0.09, nesterov=True)

#rmsprop with momemntum with default discount factor of 0.9 per Keras
rmsprop_with_momentum = RMSprop(learning_rate=1e-1,momentum=0.09)

# Adam -
# beta_1 = The exponential decay rate for the 1st moment estimates
# beta_2 = The exponential decay rate for the 2nd moment estimates
adam = Adam(learning_rate=lr, beta_1=0.89, beta_2 = 0.9)

optimizers_with_default = [SGD(), SGD(momentum=0.09), SGD(momentum=0.09,nesterov=True), RMSprop(momentum=0.09), Adam()]

optimizers = [sgd, sgd_with_momentum, sgd_with_momentum_nestrov, rmsprop_with_momentum, adam]

lr_schedule = ExponentialDecay(initial_learning_rate=1e-2,decay_steps=10000,decay_rate=0.9)
optimizers_with_lr_schedule = [SGD(learning_rate=lr_schedule),SGD(learning_rate=lr_schedule,momentum=0.09),SGD(learning_rate=lr_schedule,momentum=0.09,nesterov=True), RMSprop(learning_rate=lr_schedule,momentum=0.09),Adam(learning_rate=lr_schedule)]

# %% [markdown]
# # Lets compile with all these optmizers and evaluate

# %%
train_with_optimizers(optimizers_with_default)
# Out:
# 0  --  <keras.optimizer_v2.gradient_descent.SGD object at 0x7f821186ba30>
# 1  --  <keras.optimizer_v2.gradient_descent.SGD object at 0x7f8214310bb0>
# 2  --  <keras.optimizer_v2.gradient_descent.SGD object at 0x7f8214310df0>
# 3  --  <keras.optimizer_v2.rmsprop.RMSprop object at 0x7f8214310c10>
# 4  --  <keras.optimizer_v2.adam.Adam object at 0x7f82143107f0>

# %%
train_with_optimizers(optimizers=optimizers)
# Out:
# 0  --  <keras.optimizer_v2.gradient_descent.SGD object at 0x7f8214310460>
# 1  --  <keras.optimizer_v2.gradient_descent.SGD object at 0x7f8214310c70>
# 2  --  <keras.optimizer_v2.gradient_descent.SGD object at 0x7f8214310be0>
# 3  --  <keras.optimizer_v2.rmsprop.RMSprop object at 0x7f8211870670>
# 4  --  <keras.optimizer_v2.adam.Adam object at 0x7f8214310ca0>

# %%
train_with_optimizers(optimizers=optimizers_with_lr_schedule)
# Out:
# 0  --  <keras.optimizer_v2.gradient_descent.SGD object at 0x7f8214310c40>
# 1  --  <keras.optimizer_v2.gradient_descent.SGD object at 0x7f8214310760>
# 2  --  <keras.optimizer_v2.gradient_descent.SGD object at 0x7f8214310670>
# 3  --  <keras.optimizer_v2.rmsprop.RMSprop object at 0x7f82143106a0>
# 4  --  <keras.optimizer_v2.adam.Adam object at 0x7f8214310610>

# %% [markdown]
# # Hyper Param Tuning

# %%
# !pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
import keras_tuner as kt

# %%
# Write a function that creates and returns a Keras model.
# Use the hp argument to define the hyperparameters during model creation.
def build_hpt_model(hp):

    # Lets build the Model
    model = Sequential()
    model.add(Input(shape=(X_train_scale.shape[1],)))
    # Hidden Layer 1
    model.add(Dense(units=hp.Int("units1",min_value=32, max_value=1024, step=16),
                    activation=hp.Choice("activation1",["relu", "tanh"])))
    model.add(Dropout(hp.Float("rate1",min_value=0.1, max_value=0.4, step=0.1)))
    model.add(BatchNormalization())
    # Hidden Layer 2
    model.add(Dense(units=hp.Int("units2",min_value=32, max_value=128, step=16),
                activation=hp.Choice("activation2",["relu", "tanh"])))
    model.add(Dropout(hp.Float("rate2",min_value=0.1, max_value=0.4, step=0.1)))
    model.add(BatchNormalization())
    # Hidden Layer 3
    model.add(Dense(units=hp.Int("units3",min_value=16, max_value=64, step=16),
            activation=hp.Choice("activation3",["relu", "tanh"])))
    model.add(Dropout(hp.Float("rate3",min_value=0.1, max_value=0.4, step=0.1)))
    model.add(BatchNormalization())

    # Output Layer - this is a binary classification
    model.add(Dense(units=1,activation='sigmoid'))


    learning_rate = hp.Float("lr", min_value=1e-4, max_value=1e-2, sampling="log")
    optimizer=Adam(learning_rate=learning_rate)
    # optimizer = SGD(learning_rate=learning_rate,momentum=0.09,nesterov=True)
    model.compile(optimizer=optimizer,loss="binary_crossentropy",metrics=["accuracy"])

    return model

# %%
build_hpt_model(kt.HyperParameters())

# %%
tuner = kt.RandomSearch(
    hypermodel=build_hpt_model,
    objective="val_accuracy",
    max_trials=3,
    executions_per_trial=2,
    overwrite=True,
    directory="my_dir",
    project_name="simpl_diabetes",
)
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 10
# units1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 1024, 'step': 16, 'sampling': 'linear'}
# activation1 (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh'], 'ordered': False}
# rate1 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.4, 'step': 0.1, 'sampling': 'linear'}
# units2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# activation2 (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh'], 'ordered': False}
# rate2 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.4, 'step': 0.1, 'sampling': 'linear'}
# units3 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 64, 'step': 16, 'sampling': 'linear'}
# activation3 (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh'], 'ordered': False}
# rate3 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.4, 'step': 0.1, 'sampling': 'linear'}
# lr (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %%
tuner.search(X_train_scale,y_train, epochs=10, validation_data=(X_val_scale, y_val))
# Out:
# Trial 3 Complete [00h 00m 09s]
# val_accuracy: 0.8028846085071564
#
# Best val_accuracy So Far: 0.8076923191547394
# Total elapsed time: 00h 00m 35s

# %%
tuner.get_best_hyperparameters()[0].get_config()['values']
# Out:
# {'units1': 960,
#  'activation1': 'relu',
#  'rate1': 0.1,
#  'units2': 128,
#  'activation2': 'tanh',
#  'rate2': 0.2,
#  'units3': 48,
#  'activation3': 'relu',
#  'rate3': 0.2,
#  'lr': 0.0036005031993975646}

# %%
# Get the top 2 models.
models = tuner.get_best_models(num_models=2)
best_model = models[0]
# Build the model.
# Needed for `Sequential` without specified `input_shape`.
# best_model.build(input_shape=(None, 28, 28))
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 960)               8640
#
#  dropout (Dropout)           (None, 960)               0
#
#  batch_normalization (Batch  (None, 960)               3840
#  Normalization)
#
#  dense_1 (Dense)             (None, 128)               123008
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_2 (Dense)             (None, 48)                6192
#
#  dropout_2 (Dropout)         (None, 48)                0
#
#  batch_normalization_2 (Bat  (None, 48)                192
#  chNormalization)
#
#  dense_3 (Dense)             (None, 1)                 49
#
# =================================================================
# Total params: 142433 (556.38 KB)
# Trainable params: 140161 (547.50 KB)
# Non-trainable params: 2272 (8.88 KB)
# _________________________________________________________________

# %%
# Take the best hyper param, little bit tune again and recreate a model
# take it to production

# %% [markdown]
# # Interpretability

# %%
# !pip install lime

# %%
# Refer to -- https://www.geeksforgeeks.org/introduction-to-explainable-aixai-using-lime/

# Importing the module for LimeTabularExplainer
import lime.lime_tabular

# Instantiating the explainer object by passing in the training set, and the extracted features
explainer_lime = lime.lime_tabular.LimeTabularExplainer(X_train_scale,
                                                        feature_names=X.columns,
                                                        verbose=True, mode='regression')

# %%
# !pip install fairlearn
# Out:
# Requirement already satisfied: fairlearn in /Users/sandipan/opt/anaconda3/lib/python3.8/site-packages (0.7.0)
# Requirement already satisfied: scikit-learn>=0.22.1 in /Users/sandipan/opt/anaconda3/lib/python3.8/site-packages (from fairlearn) (0.23.2)
# Requirement already satisfied: scipy>=1.4.1 in /Users/sandipan/opt/anaconda3/lib/python3.8/site-packages (from fairlearn) (1.5.4)
# Requirement already satisfied: numpy>=1.17.2 in /Users/sandipan/opt/anaconda3/lib/python3.8/site-packages (from fairlearn) (1.19.5)
# Requirement already satisfied: pandas>=0.25.1 in /Users/sandipan/opt/anaconda3/lib/python3.8/site-packages (from fairlearn) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/sandipan/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.1->fairlearn) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/sandipan/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.1->fairlearn) (2021.1)
# Requirement already satisfied: joblib>=0.11 in /Users/sandipan/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.1->fairlearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sandipan/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.1->fairlearn) (2.1.0)
# Requirement already satisfied: six>=1.5 in /Users/sandipan/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->fairlearn) (1.15.0)
# WARNING: There was an error checking the latest version of pip.

# %%
import shap

# %%
ex = shap.KernelExplainer(models[0].predict, X_train_scale)
# Out:
# Using 587 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.

# %%
shap_vals =ex.shap_values(X_test_scale)
shap.summary_plot(shap_vals, X_test_scale, X.columns)
# Out:
# 100%|██████████| 77/77 [02:47<00:00,  2.17s/it]
